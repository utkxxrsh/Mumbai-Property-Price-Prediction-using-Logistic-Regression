# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7ec2123a-b072-406f-950b-a27be635cc80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ec2123a-b072-406f-950b-a27be635cc80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("mumbai.csv")

# %%
data
# Out:
#            price                                            Address    area  \
# 0     22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1     35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2     31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3     18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4     13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# ...          ...                                                ...     ...
# 6250  19500000.0   Yari Road, Mumbai - Western Suburbs, Maharashtra   810.0
# 6251  22000000.0  502., Hari Om Nagar, Mumbai - North Mumbai, Ma...  1400.0
# 6252  20000000.0  Lokhandwala Complex, Andheri West, Lokhandwala...   750.0
# 6253  11000000.0         Sion, Mumbai - Central Mumbai, Maharashtra   700.0
# 6254  15000000.0    Mulund West, Mumbai - Central Line, Maharashtra   900.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             6255 non-null   float64
#  1   Address           6255 non-null   object
#  2   area              6255 non-null   float64
#  3   latitude          6255 non-null   float64
#  4   longitude         6255 non-null   float64
#  5   Bedrooms          6255 non-null   float64
#  6   Bathrooms         6255 non-null   float64
#  7   Balcony           2376 non-null   float64
#  8   Status            5774 non-null   object
#  9   neworold          6255 non-null   object
#  10  parking           2129 non-null   float64
#  11  Furnished_status  3600 non-null   object
#  12  Lift              1678 non-null   float64
#  13  Landmarks         2617 non-null   object
#  14  type_of_building  6255 non-null   object
#  15  desc              6255 non-null   object
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 16 to 6224
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             175 non-null    float64
#  1   Address           175 non-null    object
#  2   area              175 non-null    float64
#  3   latitude          175 non-null    float64
#  4   longitude         175 non-null    float64
#  5   Bedrooms          175 non-null    float64
#  6   Bathrooms         175 non-null    float64
#  7   Balcony           175 non-null    float64
#  8   Status            175 non-null    object
#  9   neworold          175 non-null    object
#  10  parking           175 non-null    float64
#  11  Furnished_status  175 non-null    object
#  12  Lift              175 non-null    float64
#  13  Landmarks         175 non-null    object
#  14  type_of_building  175 non-null    object
#  15  desc              175 non-null    object
# ...

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['price'],axis=1)
y=data['price']

# %%
x
# Out:
#                                                 Address    area   latitude  \
# 16    Rustomjee Seasons Madhusudan Kalelkar Rd near ...  3180.0  19.057490
# 17    Vazira naka, Borivali West, Mumbai - Western S...  1000.0  19.233532
# 19    Swapna Nagari Near Vasant Garden Mulund West, ...   875.0  19.174674
# 22    Goregaon East, Mumbai, Goregaon East, Mumbai -...  2430.0  19.154784
# 25    Andheri west., Seven Bungalows, Mumbai - Weste...   900.0  19.128420
# ...                                                 ...     ...        ...
# 5808    Peddar Road, Mumbai - South Mumbai, Maharashtra   870.0  18.968870
# 5815  Maharashtra, Mumbai - Western Suburbs, Jankaly...   872.0  19.201590
# 6083  Worli Sea Face, Mumbai, Maharashtra, Worli Sea...  1920.0  19.008970
# 6222   Pali Hill, Mumbai - Western Suburbs, Maharashtra  1580.0  19.067380
# 6224   Malabar Hill, Mumbai - South Mumbai, Maharashtra  1800.0  18.954286
#
# ...

# %%
y
# Out:
# 16      102000000.0
# 17       22500000.0
# 19       15500000.0
# 22       55000000.0
# 25       25000000.0
#            ...
# 5808     57500000.0
# 5815     11000000.0
# 6083    100000000.0
# 6222    110000000.0
# 6224    160000000.0
# Name: price, Length: 175, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'area'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'longitude'}>],
#        [<Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Bathrooms'}>,
#         <Axes: title={'center': 'Balcony'}>],
#        [<Axes: title={'center': 'parking'}>,
#         <Axes: title={'center': 'Lift'}>,
#         <Axes: title={'center': 'Price_sqft'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['Bedrooms']=np.log(train_data['Bedrooms']+1)
train_data['Bathrooms']=np.log(train_data['Bathrooms']+1)
train_data['Balcony']=np.log(train_data['Balcony']+1)
train_data['Lift']=np.log(train_data['Lift']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'area'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'longitude'}>],
#        [<Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Bathrooms'}>,
#         <Axes: title={'center': 'Balcony'}>],
#        [<Axes: title={'center': 'parking'}>,
#         <Axes: title={'center': 'Lift'}>,
#         <Axes: title={'center': 'Price_sqft'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
train_data=train_data.join(pd.get_dummies(train_data.neworold)).drop(['neworold'],axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="price",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

x_train,y_train=train_data.drop(['price'],axis=1),train_data['price']

x_train_s=scaler.fit_transform(x_train)

reg.fit(x_train_s,y_train)
# Out:
# LinearRegression()

# %%
train_data = train_data.drop('Address', axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data = train_data.drop('Landmarks', axis=1)

# %%
train_data = train_data.drop('desc', axis=1)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)

test_data['Bedrooms']=np.log(test_data['Bedrooms']+1)
test_data['Bathrooms']=np.log(test_data['Bathrooms']+1)
test_data['Balcony']=np.log(test_data['Balcony']+1)
test_data['Lift']=np.log(test_data['Lift']+1)

test_data=test_data.join(pd.get_dummies(test_data.type_of_building)).drop(['type_of_building'],axis=1)
test_data=test_data.join(pd.get_dummies(test_data.Status)).drop(['Status'],axis=1)
test_data=test_data.join(pd.get_dummies(test_data.Furnished_status)).drop(['Furnished_status'],axis=1)
test_data=test_data.join(pd.get_dummies(test_data.neworold)).drop(['neworold'],axis=1)



test_data = test_data.drop('Address', axis=1)
test_data = test_data.drop('desc', axis=1)
test_data = test_data.drop('Landmarks', axis=1)

x_test,y_test=test_data.drop(['price'],axis=1),test_data['price']

# %%
test_data
# Out:
#         area   latitude  longitude  Bedrooms  Bathrooms   Balcony  parking  \
# 5366   675.0  19.089260  72.889250  1.098612   1.098612  1.098612      1.0
# 25     900.0  19.128420  72.819880  1.098612   1.098612  0.693147      2.0
# 5451  4000.0  19.119343  72.864586  1.945910   1.945910  2.197225      4.0
# 302    950.0  19.119272  72.864601  1.098612   1.098612  0.693147      1.0
# 343   2450.0  19.055229  72.830829  1.609438   1.609438  1.609438      2.0
# 276   1370.0  19.080942  72.892342  1.386294   1.386294  0.693147      2.0
# 3143   950.0  19.219350  72.852860  1.098612   1.098612  1.386294     10.0
# 346   2500.0  19.119421  72.863708  1.386294   1.386294  1.609438      2.0
# 2779  1242.0  19.209944  72.830869  1.098612   1.098612  1.609438      1.0
# 5808   870.0  18.968870  72.808820  1.098612   1.098612  0.693147      1.0
# 1291  1100.0  19.123335  72.871582  1.098612   1.098612  1.098612      1.0
# ...

# %%
train_data
# Out:
#         area   latitude  longitude  Bedrooms  Bathrooms   Balcony  parking  \
# 1287   830.0  19.214048  72.855255  1.098612   1.098612  1.098612      1.0
# 2432   925.0  19.118958  72.864105  1.098612   1.098612  0.693147      1.0
# 2004  1000.0  19.289045  72.889832  1.098612   1.098612  1.098612      1.0
# 629    715.0  19.213390  72.931420  1.098612   1.098612  0.693147    603.0
# 5194   900.0  19.225805  73.146484  1.098612   1.098612  0.693147      1.0
# ...      ...        ...        ...       ...        ...       ...      ...
# 5434   870.0  19.384014  72.830994  1.098612   1.098612  0.693147      2.0
# 556   1500.0  19.056340  72.917320  1.386294   1.386294  1.098612      1.0
# 1133   800.0  19.118958  72.864052  1.098612   1.098612  0.693147      1.0
# 5778  1035.0  19.040233  72.860180  1.098612   1.098612  1.386294      2.0
# 4847  1790.0  19.119677  72.905081  1.386294   1.386294  0.693147      2.0
#
#           Lift    Price_sqft       price  Flat  Individual House  \
# ...

# %%
x_test_s=scaler.transform(x_test)

# %%
reg.score(x_test_s,y_test)
# Out:
# 0.943602728024106
